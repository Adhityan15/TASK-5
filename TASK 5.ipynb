# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df=pd.read_csv("heart.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.hist(bins=50,grid=True,figsize=(20,15));

# %%
df.hist(bins=50,grid=False,figsize=(20,10));

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
questions=["1. how many people have heart disease and how many people doesnt have heart disease?",
           "2. people of wich sex has most heart disease",
           "3. people of which sex has which type of chest pain most?",
           "4. people with which chest pain are most pron to have heart disease"
           "5. people having blood sugar by sex"
           "6. people having cholestrol type by sex"
            "7. people having sugar and heart disease"] 
questions
# Out:
# ['1. how many people have heart disease and how many people doesnt have heart disease?',
#  '2. people of wich sex has most heart disease',
#  '3. people of which sex has which type of chest pain most?',
#  '4. people with which chest pain are most pron to have heart disease5. people having blood sugar by sex6. people having cholestrol type by sex7. people having sugar and heart disease']

# %%
#1. how many people have heart disease and how many people doesnt have heart disease?
df.target.value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
#bar chart
df.target.value_counts().plot(kind='bar',color=["orchid","salmon"])
plt.title("heart disease values")
plt.xlabel("1=heart dsease,0=No heart disease")
plt.ylabel("amount");

# %%
#pie chart
df.target.value_counts().plot(kind='pie',figsize=(8,6))
plt.legend(["disease","no disease"]);

# %%
#2. people of wich sex has most heart disease
df.sex.value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
#pie chart 

df.sex.value_counts().plot(kind="pie",figsize=(8,6))
plt.title("male female ratio")
plt.legend(["postive","negative"])

# %%
df.target.value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
df.target.value_counts().plot(kind="pie",figsize=(8,6))
plt.title("disease positive")
plt.legend(["postive","negative"])

# %%
pd.crosstab(df.target,df.sex)
# Out:
# sex       0    1
# target
# 0        86  413
# 1       226  300

# %%
sns.countplot(x="target",data=df,hue="sex")
plt.title("heart Disease frequency for sex")
plt.xlabel("0=no heart disease, 1 heart disease")
# Out:
# Text(0.5, 0, '0=no heart disease, 1 heart disease')

# %%
#3. people of which sex has which type of chest pain

# %%
df.cp.value_counts()
# Out:
# cp
# 0    497
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64

# %%
pd.crosstab(df.cp,df.sex)
# Out:
# sex    0    1
# cp
# 0    133  364
# 1     57  110
# 2    109  175
# 3     13   64

# %%
sns.countplot(x="cp",data=df,hue="sex")
plt.title("type of chest pain for sex")
plt.xlabel("0=no , 1 light ,2 mild , 3 severee")
# Out:
# Text(0.5, 0, '0=no , 1 light ,2 mild , 3 severee')

# %%
#4. people with which chest pain are most pron to have heart disease

# %%
pd.crosstab(df.cp,df.target)
# Out:
# target    0    1
# cp
# 0       375  122
# 1        33  134
# 2        65  219
# 3        26   51

# %%
sns.countplot(x="cp",data=df,hue="target")
plt.title("people with which chest pain are most pron to have heart disease")
plt.xlabel("orange=female , blue=male,0=no , 1 light ,2 mild , 3 severe")
# Out:
# Text(0.5, 0, 'orange=female , blue=male,0=no , 1 light ,2 mild , 3 severe')

# %%
#5 people having blood sugar by sex

# %%
df.fbs.value_counts().plot(kind='bar',color=["orchid","salmon"])
plt.title("blood sugar")
plt.xlabel("1= high,0=low")
plt.ylabel("amount");

# %%
pd.crosstab(df.fbs,df.sex)
# Out:
# sex    0    1
# fbs
# 0    270  602
# 1     42  111

# %%
sns.countplot(x="fbs",data=df,hue="sex")
plt.title("people with sugar by sex")
plt.xlabel("orange=female , blue=male,0=no , 1 = yes")
# Out:
# Text(0.5, 0, 'orange=female , blue=male,0=no , 1 = yes')

# %%
#6. people having cholestrol type by sex

# %%
df.chol.value_counts().plot(kind='bar',color=["orchid","salmon"])
plt.title("blood cholestrol")
plt.xlabel("0-10= mild,11-20=high")
plt.ylabel("amount");

# %%
pd.crosstab(df.chol,df.sex)
# Out:
# sex   0  1
# chol
# 126   0  3
# 131   0  3
# 141   3  0
# 149   4  4
# 157   0  4
# ...  .. ..
# 394   3  0
# 407   4  0
# 409   3  0
# 417   3  0
# 564   3  0
#
# [152 rows x 2 columns]

# %%
sns.countplot(x="chol",data=df,hue="sex")
plt.title("cholestrol by sex")
plt.xlabel(",0=no , 1 = yes")
# Out:
# Text(0.5, 0, ',0=no , 1 = yes')

# %%
#7. people having sugar and heart disease

# %%
pd.crosstab(df.fbs,df.target)
# Out:
# target    0    1
# fbs
# 0       417  455
# 1        82   71

# %%
sns.countplot(x="fbs",data=df,hue="target")
plt.title("people with sugar pron to have heart disease")
plt.xlabel("orange=female , blue=male,0=no , 1 yes")
# Out:
# Text(0.5, 0, 'orange=female , blue=male,0=no , 1 yes')
